# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip -o -q /content/drive/MyDrive/cervisense-ai_export.zip -d /content/ > /dev/null
# !rm /content/drive/MyDrive/cervisense-ai_export.zip
# %cd /content/cervisense-ai
# !pip install -r requirements_colab.txt -q
# !nvidia-smi

# %%
# !python training/train_finetune.py --config configs/finetune_config.yaml

# %%
import shutil
shutil.copy('checkpoints/finetune/best_finetune.pth', '/content/drive/MyDrive/cervisense/checkpoints/best_finetune.pth')
